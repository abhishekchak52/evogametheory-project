# %%
# %pylab inline

b=10
c=1

def fitness(member, population):
    
    num_A = population.count('A')
    N = len(population)
    fitnesses = [
        b*num_A  - N*c,
        b*num_A
        ]
#     return fitnesses
    normed_fitness = np.array(fitnesses)/sum(fitnesses)
    
    return normed_fitness#[0] if member =='A' else normed_fitness[1]

def repeated_pd_game(population):
    freq_history = []
    while True:
        freq_history.append(population.count('A')/N)
        if population.count('A') in {0,N}: # Either species is fixed
            break
        else:            
            reproduce,replace = np.random.randint(0,N,size=2)
            if np.random.random() < fitness(population[reproduce], population):
                population[replace] = population[reproduce] 
    return freq_history
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
N=100
population  =[ 'A' if i< 1 else 'B' for i in range(N)]

# %%
for i in range(100):
    print(fitness(i,population))
# Out:
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
# [-90, 10]
